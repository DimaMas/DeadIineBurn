# %%
# %matplotlib inline  

import pandas

import matplotlib
import numpy
import matplotlib.pyplot as plt

df = pandas.read_csv("data.csv")
df['time'].plot(kind='bar')
print(df.time.describe())
df.plot.kde()
from scipy import stats
print(stats.kstest(df, 'norm', (df.mean(), df.std()), N=len(df)))
# Out:
# count    30.000000
# mean      9.842000
# std       1.327867
# min       7.000000
# 25%       9.460000
# 50%       9.910000
# 75%      10.230000
# max      15.150000
# Name: time, dtype: float64
# KstestResult(statistic=0.999967977466222, pvalue=2.915417581257424e-135)
